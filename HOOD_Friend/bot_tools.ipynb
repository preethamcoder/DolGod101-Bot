# %%
from pycricbuzz import Cricbuzz

# %%
import pandas as pd

# %%
data = pd.read_csv('bhagavad-gita.csv')
data
# Out:
#      Unnamed: 0  title                                         devanagari  \
# 0             0   1.10  धृतराष्ट्र उवाच ।\r\nधर्मक्षेत्रे कुरुक्षेत्रे...
# 1             1   1.20  सञ्जय उवाच ।\r\nदृष्ट्वा तु पाण्डवानीकं व्यूढं...
# 2             2   1.30  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।\r...
# 3             3   1.40  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि ।\r\nयुय...
# 4             4   1.50  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् ।\r\n...
# ..          ...    ...                                                ...
# 695         695  18.74  संजय उवाच ।\r\nइत्यहं वासुदेवस्य पार्थस्य च मह...
# 696         696  18.75  व्यासप्रसादाच्छ्रुतवानेतद्गुह्यमहं परम् ।\r\nय...
# 697         697  18.76  राजन्संस्मृत्य संस्मृत्य संवादमिममद्भुतम् ।\r\...
# 698         698  18.77  तच्च संस्मृत्य संस्मृत्य रूपमत्यद्भुतं हरेः ।\...
# 699         699  18.78  यत्र योगेश्वरः कृष्णो यत्र पार्थो धनुर्धरः ।\r...
#
#                                             verse_text  \
# ...

# %%
c = Cricbuzz()
matches = c.matches()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ...
